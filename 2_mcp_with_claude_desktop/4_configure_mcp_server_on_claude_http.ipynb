# %% [markdown]
# ### Use streamable http protocol for connecting to MCP server
#
# In this demo, we will configure claude desktop - the AI assistant to connect to MCP server via streamable http protocol
#
# We will use Uniprot MCP server for this. We will run this MCP server locally which will expose the server in localhost and then we will connect Agent to this MCP server via http protocol.
#
# Steps
# 1. Download uniprot MCP server github
# 2. Install MCP server
# 3. Start the server
# 4. Configure claude desktop json
# 5. Interact with Agent

# %% [markdown]
# #### Uniprot MCP server
# This is not official MCP server from uniprot
#
# https://github.com/QuentinCody/uniprot-mcp-server

# %%
# Clone the repo by 
# git clone https://github.com/QuentinCody/uniprot-mcp-server.git
# cd  uniprot-mcp-server

# install the server
# npm install

# Launch server. Opens at http://localhost:8787
# npm run dev

# %% [markdown]
# #### Add Uniprot mcp server on claude
#
# Go to settings -> Developer -> Edit config. Restart
#
# If you have enabled developer mode (help -> enable developer mode), then you can go to
#
# Menu-> developer -> reload mcp configuration
#
# Once uv is installed, on windows cmd prompt get path by
#
# ```sh
# where npx
# ```
#
# Use that path and add below json in config
#
# ```json
#     "uniprot": {
#       "command": "C:\\Program Files\\nodejs\\npx.cmd",
#       "args": [
#         "mcp-remote",
#         "http://localhost:8787/mcp"
#       ]
#     }
# ```
#
# Can try below queries
# ```sh
# # Get uniprot ids for gene TP53. just 5 is enough. only uniprot ids
# # describe in 2 lines about P04637
# ```
